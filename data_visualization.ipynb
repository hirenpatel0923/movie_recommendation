# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#data that contains movie personality calculated using pooling layers in tensorflow.
df = pd.read_csv('KNN_DATA.csv')
X = df.iloc[:,1:].as_matrix()

# %%
#user personalities based on their comments on movie calculated like movie personality
z = np.array([[7.092207670211791992e-01,4.852280020713806152e-01],
              [8.701885938644409180e-01,8.108747005462646484e-01],
              [6.476376652717590332e-01,5.138314366340637207e-01],
              [5.683318376541137695e-01,7.279945611953735352e-01],
              [4.801380634307861328e-01,5.642787218093872070e-01],
              [7.355208396911621094e-01,5.564780235290527344e-01],
              [0.5704621,0.42586628],
              [0.5663941,0.4129734],
              [0.38411194,0.29826048]
             ])

# %%
plt.scatter(X[:,0],X[:,1] , s=50, cmap='viridis', label='Average user personality of a movie')
plt.scatter(z[:,0],z[:,1], c = 'red', s=100, label='single user review personality')
plt.legend(loc='upper left')
plt.show()

# %%
#here blue dots represents the average personality of a movie calculated by reviews of user
#red dots presents the review personality of user
